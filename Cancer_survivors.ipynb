# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

cancer_surv = pd.read_csv('D:/upgrad/statsandEDA/haberman.csv')

# %%
cancer_surv.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
cancer_surv.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
#Change the column names as below:

cancer_surv = pd.read_csv('D:/upgrad/statsandEDA/haberman.csv',header=None, names=["Age","Operation Year","Axi_nodes_det","Surv_status"])

# %%
cancer_surv.columns
# Out:
# Index(['Age', 'Operation Year', 'Axi_nodes_det', 'Surv_status'], dtype='object')

# %%
cancer_surv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# Age               306 non-null int64
# Operation Year    306 non-null int64
# Axi_nodes_det     306 non-null int64
# Surv_status       306 non-null int64
# dtypes: int64(4)
# memory usage: 9.6 KB

# %%
cancer_surv.head()
# Out:
#    Age  Operation Year  Axi_nodes_det  Surv_status
# 0   30              64              1            1
# 1   30              62              3            1
# 2   30              65              0            1
# 3   31              59              2            1
# 4   31              65              4            1

# %%
cancer_surv.tail()
# Out:
#      Age  Operation Year  Axi_nodes_det  Surv_status
# 301   75              62              1            1
# 302   76              67              0            1
# 303   77              65              3            1
# 304   78              65              1            2
# 305   83              58              2            2

# %%
print(cancer_surv.describe())
print("*"*60)
print(cancer_surv.info())
# Out:
#               Age  Operation Year  Axi_nodes_det  Surv_status
# count  306.000000      306.000000     306.000000   306.000000
# mean    52.457516       62.852941       4.026144     1.264706
# std     10.803452        3.249405       7.189654     0.441899
# min     30.000000       58.000000       0.000000     1.000000
# 25%     44.000000       60.000000       0.000000     1.000000
# 50%     52.000000       63.000000       1.000000     1.000000
# 75%     60.750000       65.750000       4.000000     2.000000
# max     83.000000       69.000000      52.000000     2.000000
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# Age               306 non-null int64
# Operation Year    306 non-null int64
# Axi_nodes_det     306 non-null int64
# Surv_status       306 non-null int64
# dtypes: int64(4)
# memory usage: 9.6 KB
# None

# %%
cancer_surv.shape
# Out:
# (306, 4)

# %%
# The entire dataset with 306 we have people with surv status as 1 and 2 1 is surrvived and 2 not survived
# 225 surrvival cases and 81 death cases

cancer_surv['Surv_status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: Surv_status, dtype: int64

# %% [markdown]
# ### Univariate analysis ( Distribution Plots, Box Plots, Voilin Plots, PDF and CDF)

# %%
sns.FacetGrid(cancer_surv, hue="Surv_status", size=5).map(sns.distplot,"Age").add_legend()
# Out:
# D:\Programs\anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## People from 50 to 60 have move survival status

# %%
sns.FacetGrid(cancer_surv, hue="Surv_status", size=5).map(sns.distplot, "Operation Year").add_legend()
# Out:
# D:\Programs\anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### People from 58 to 68 have survived more

# %%
sns.boxplot(x="Surv_status", y="Age", data=cancer_surv)
plot.show()

# %%
sns.boxplot(x="Surv_status", y="Operation Year", data=cancer_surv)
plot.show()

# %%
#Pair Plot

sns.pairplot(cancer_surv, hue="Surv_status")
plot.show()
