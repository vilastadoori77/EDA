# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
# Reading the csv into a dataframe

sales_df= pd.read_csv("D:/upgrad/datasets/SalesKaggle3.csv")

# %%
sales_df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
sales_df.describe(include='all')
# Out:
#                 Order File_Type    SKU_number      SoldFlag     SoldCount  \
# count   198917.000000    198917  1.989170e+05  75996.000000  75996.000000
# unique            NaN         2           NaN           NaN           NaN
# top               NaN    Active           NaN           NaN           NaN
# freq              NaN    122921           NaN           NaN           NaN
# mean    106483.543242       NaN  8.613626e+05      0.171009      0.322306
# std      60136.716784       NaN  8.699794e+05      0.376519      1.168615
# min          2.000000       NaN  5.000100e+04      0.000000      0.000000
# 25%      55665.000000       NaN  2.172520e+05      0.000000      0.000000
# 50%     108569.000000       NaN  6.122080e+05      0.000000      0.000000
# 75%     158298.000000       NaN  9.047510e+05      0.000000      0.000000
# max     208027.000000       NaN  3.960788e+06      1.000000     73.000000
#
#        MarketingType  ReleaseNumber  New_Release_Flag  StrengthFactor  \
# ...

# %%
#number of entries in the dataset

sales_df.shape
# Out:
# (198917, 14)

# %%
#Total number of product and unique values
sales_df.nunique()
# Out:
# Order               198917
# File_Type                2
# SKU_number          133360
# SoldFlag                 2
# SoldCount               37
# MarketingType            2
# ReleaseNumber           71
# New_Release_Flag         2
# StrengthFactor      197424
# PriceReg             11627
# ReleaseYear             85
# ItemCount              501
# LowUserPrice         12102
# LowNetPrice          15403
# dtype: int64

# %%
sales_df.head(10)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
# 5      8  Historical      214948       0.0        0.0             D
# 6      9  Historical      484059       0.0        0.0             D
# 7     10  Historical      146401       0.0        0.0             D
# 8     11  Historical      110568       0.0        0.0             D
# 9     12  Historical      764270       0.0        0.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# ...

# %%
#Count of the historical and active state, (we need only analyze the active state products):
print(sales_df[sales_df['File_Type']=='Historical']['SKU_number'].count())
print('********************')
print(sales_df[sales_df['File_Type']=='Active']['SKU_number'].count())
# Out:
# 75996
# ********************
# 122921

# %%
#We split the data into two dataframes Active and Historical

sales_df_hist = sales_df[sales_df['File_Type']=='Historical']

sales_df_active = sales_df[sales_df['File_Type']=='Active']

# %%
sales_df_hist.shape
# Out:
# (75996, 14)

# %%
sales_df_active.shape
# Out:
# (122921, 14)

# %% [markdown]
# ## Univariate and Bivariate Analysis

# %%
sales_df.columns
# Out:
# Index(['Order', 'File_Type', 'SKU_number', 'SoldFlag', 'SoldCount',
#        'MarketingType', 'ReleaseNumber', 'New_Release_Flag', 'StrengthFactor',
#        'PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice'],
#       dtype='object')

# %%
sales_df['MarketingType'].value_counts().plot.bar(title="Frequency Marketing Type")

# %%
import seaborn as sns
col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(16,12))

for i, col_val in enumerate(col_names):

    sns.distplot(sales_df_hist[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)

plt.show()

# %%
sales_df_hist = sales_df_hist.drop([
      'Order', 'File_Type','SKU_number','SoldFlag','MarketingType','ReleaseNumber','New_Release_Flag'
], axis=1)

# %%
sales_df_hist.columns
# Out:
# Index(['SoldCount', 'StrengthFactor', 'PriceReg', 'ReleaseYear', 'ItemCount',
#        'LowUserPrice', 'LowNetPrice'],
#       dtype='object')

# %%
sns.pairplot(sales_df_hist)

# %%
# To check if there are any null values in the data set
sales_df.isnull().values.any()
# Out:
# True

# %%
sales_df.isnull().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag            122921
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %%
# Fill the values of 0 in these columns
sales_df['SoldFlag'].fillna(value=0, inplace=True)

# %%
sales_df.isnull().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag                 0
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %%
sales_df['SoldCount'].fillna(value=0, inplace=True)

# %%
col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=sales_df_hist[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['StrengthFactor','PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
    x = sales_df_hist[col_val][:1000]
    sns.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = sales_df_hist.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True)
