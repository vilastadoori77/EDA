# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.xlabel("Gold Price")
plt.ylabel("Silver Price")
plt.title("Gold Silver Variation")
df = pd.read_csv('D:/upgrad/datasets/EDA_Gold_Silver_prices.csv')
df.head()

plt.scatter(df['GoldPrice'], df['SilverPrice'])
plt.show()

# %%
correlation_variable =np.corrcoef(df['GoldPrice'], df['SilverPrice'])
correlation_variable
# Out:
# array([[1.        , 0.95425596],
#        [0.95425596, 1.        ]])

# %%
df.corr().abs()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
df.columns
# Out:
# Index(['Month', 'SilverPrice', 'GoldPrice'], dtype='object')

# %%
from datetime import datetime
import pandas as pd

data = list(df['Month'])
data
df_backup=df

# %%
df['Month'] = list(map(lambda x: datetime.strptime(x, '%b-%y').strftime('%m-%Y'), df['Month']))
print(df)
# Out:
#        Month  SilverPrice  GoldPrice
# 0    03-1997       186.48   12619.24
# 1    04-1997       170.65   12338.59
# 2    05-1997       170.44   12314.94
# 3    06-1997       169.96   12202.78
# 4    07-1997       155.80   11582.07
# 5    08-1997       162.16   11640.38
# 6    09-1997       172.13   11755.57
# 7    10-1997       181.57   11769.89
# 8    11-1997       187.99   11370.19
# 9    12-1997       224.16   11324.79
# 10   01-1998       230.08   11378.25
# 11   02-1998       261.75   11576.23
# 12   03-1998       243.81   11690.84
# 13   04-1998       249.37   12225.02
# 14   05-1998       225.54   12075.24
# 15   06-1998       222.24   12349.86
# 16   07-1998       232.46   12450.03
# 17   08-1998       220.73   12142.73
# 18   09-1998       213.74   12287.69
# 19   10-1998       211.80   12531.16
# 20   11-1998       211.21   12463.97
# 21   12-1998       207.96   12412.18
# 22   01-1999       219.44   12203.20
# 23   02-1999       235.52   12203.06
# ...

# %%
start, end = pd.to_datetime(["01-2008", "12-2008"], format='%m-%Y')
df['Month'] =  pd.to_datetime(df['Month'], format='%m-%Y')

# %%
dataset_2008 = df[(df['Month'] >= start) & (df['Month'] <= end)]
dataset_2008
# Out:
#          Month  SilverPrice  GoldPrice
# 130 2008-01-01       632.29   35025.78
# 131 2008-02-01       701.87   36642.46
# 132 2008-03-01       775.49   39082.77
# 133 2008-04-01       700.96   36416.00
# 134 2008-05-01       718.20   37435.38
# 135 2008-06-01       729.63   38087.88
# 136 2008-07-01       773.80   40256.56
# 137 2008-08-01       625.97   36026.85
# 138 2008-09-01       555.58   37815.02
# 139 2008-10-01       507.20   39235.79
# 140 2008-11-01       483.55   37284.82
# 141 2008-12-01       501.82   39696.27

# %%
round(dataset_2008.corr().abs(),2)
# Out:
#              SilverPrice  GoldPrice
# SilverPrice         1.00       0.01
# GoldPrice           0.01       1.00

# %%
df.tail(100)
# Out:
#          Month  SilverPrice  GoldPrice
# 141 2008-12-01       501.82   39696.27
# 142 2009-01-01       556.73   41938.42
# 143 2009-02-01       661.39   46416.55
# 144 2009-03-01       672.41   47387.48
# 145 2009-04-01       626.90   44573.36
# 146 2009-05-01       684.92   45070.86
# 147 2009-06-01       700.33   45178.09
# 148 2009-07-01       649.34   45317.28
# 149 2009-08-01       697.27   45872.80
# 150 2009-09-01       798.50   48273.82
# 151 2009-10-01       806.59   48737.49
# 152 2009-11-01       832.51   52484.94
# 153 2009-12-01       822.77   52912.18
# 154 2010-01-01       815.23   51344.51
# 155 2010-02-01       735.29   50745.87
# 156 2010-03-01       780.50   50654.61
# 157 2010-04-01       808.47   51115.41
# 158 2010-05-01       843.70   55173.35
# 159 2010-06-01       859.34   57410.36
# 160 2010-07-01       841.85   55916.83
# 161 2010-08-01       856.25   56616.02
# 162 2010-09-01       946.05   58511.77
# 163 2010-10-01      1039.07   59609.35
# ...

# %%
df.dtypes
# Out:
# Month          datetime64[ns]
# SilverPrice           float64
# GoldPrice             float64
# dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('D:/upgrad/datasets/currencies.csv')
df.head()
round(df.corr(method='kendall'),2)
# Out:
#                             Chinese Yuan  Euro  Japanese Yen  \
# Chinese Yuan                        1.00  0.07          0.09
# Euro                                0.07  1.00         -0.56
# Japanese Yen                        0.09 -0.56          1.00
# U.K. Pound Sterling                 0.11  0.53         -0.82
# U.S. Dollar                         0.40 -0.13          0.16
# Algerian Dinar                      0.82  0.28         -0.21
# Australian Dollar                   0.18  0.38         -0.47
# Bahrain Dinar                       0.40 -0.13          0.16
# Botswana Pula                       0.42  0.44         -0.33
# Brazilian Real                      0.11  0.45         -0.47
# Brunei Dollar                       0.36  0.07         -0.33
# Canadian Dollar                     0.00  0.51         -0.67
# Chilean Peso                        0.00  0.27         -0.51
# Czech Koruna                       -0.11  0.79         -0.43
# ...

# %%
df_corr=round(df.corr(method='kendall'),2)
df_corr
# Out:
#                             Chinese Yuan  Euro  Japanese Yen  \
# Chinese Yuan                        1.00  0.07          0.09
# Euro                                0.07  1.00         -0.56
# Japanese Yen                        0.09 -0.56          1.00
# U.K. Pound Sterling                 0.11  0.53         -0.82
# U.S. Dollar                         0.40 -0.13          0.16
# Algerian Dinar                      0.82  0.28         -0.21
# Australian Dollar                   0.18  0.38         -0.47
# Bahrain Dinar                       0.40 -0.13          0.16
# Botswana Pula                       0.42  0.44         -0.33
# Brazilian Real                      0.11  0.45         -0.47
# Brunei Dollar                       0.36  0.07         -0.33
# Canadian Dollar                     0.00  0.51         -0.67
# Chilean Peso                        0.00  0.27         -0.51
# Czech Koruna                       -0.11  0.79         -0.43
# ...

# %%
def plot_corr(df,size=40):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    sns.heatmap(corr, cmap="YlGnBu_r", annot=True)
    plt.show()

# %%
plot_corr(df)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('D:/upgrad/datasets/nas.csv')
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...
