# %%
import pandas as pd
import glob

path = r'D:\upgrad\statsandEDA\gdp\NAD' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding = 'unicode_escape')
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True, sort=True)
frame
# Out:
#         2011-12     2012-13     2013-14      2014-15      2015-16     2016-17  \
# 0     9400805.0  11186428.0  12895568.0   14819416.0   17326726.0  20386004.0
# 1     5204052.0   6123041.0   7114707.0    7893514.0    8644285.0   9717089.0
# 2     2758776.0   3358438.0   3643026.0    4309078.0    5155487.0   5979648.0
# 3      250314.0    253029.0    280493.0     346160.0     340550.0    335487.0
# 4     1187663.0   1451920.0   1857342.0    2270664.0    3186404.0   4353780.0
# 5     1416194.0   1459027.0   1419200.0    1484300.0    1633100.0   1757565.0
# 6    10816999.0  12645455.0  14314768.0   16303716.0   18959826.0  22143569.0
# 7     5070622.0   4237657.0   4242337.0    4672266.0    5078685.0   5740816.0
# 8     1076517.0    713029.0   1014130.0    1151729.0    1251910.0   1298947.0
# 9     3702645.0   3759004.0   4065131.0    4664889.0    4986189.0   5467732.0
# 10    9849784.0   8709690.0   9321598.0   10488884.0   11316784.0  12507496.0
# ...

# %%
import pandas as pd
import glob

path = r'D:\upgrad\statsandEDA\gdp\NAD' # use your path
all_files = glob.glob(path + "/*.csv")

for i, f in enumerate (all_files):
    if i == 0:        
        df = pd.read_csv(f, index_col=None, header=0, encoding = 'unicode_escape')
        fname = str(all_files[i]).split('\\')[-1:][0]
        fname1 = str(fname).split('-')[1]
        print(fname1)
        df['fname'] = fname1
    else:
        tmp = pd.read_csv(f, index_col=None, header=0, encoding = 'unicode_escape')
        #tmp['fname'] = f
        #df = df.append(tmp)
        fname = str(all_files[i]).split('\\')[-1:][0]
        fname1 = str(fname).split('-')[1]
        print(fname1)

#df.head()
# Out:
# Andhra_Pradesh
# Arunachal_Pradesh
# Assam
# Bihar
# Chhattisgarh
# Goa
# Gujarat
# Haryana
# Himachal_Pradesh
# Jharkhand
# Karnataka
# Kerala
# Madhya_Pradesh
# Maharashtra
# Manipur
# Meghalaya
# Mizoram
# Nagaland
# Odisha
# Punjab
# Rajasthan
# Sikkim
# Tamil_Nadu
# Telangana
# Tripura
# Uttarakhand
# Uttar_Pradesh

# %%
import pandas as pd
import glob
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns',500)
path = r'D:\upgrad\statsandEDA\gdp\NAD' # use your path
all_files = glob.glob(path + "/*.csv")
li=[]
for i, f in enumerate (all_files):
    if i == 0:        
        df = pd.read_csv(f, index_col=None, header=0, encoding = 'unicode_escape')
        fname = str(all_files[i]).split('\\')[-1:][0]
        fname1 = str(fname).split('-')[1]
        #print(fname1)
        df['state_name']=fname1
        df2= df[['Item','state_name','2014-15']]
        li.append(df2)
        
    else:
        tmp = pd.read_csv(f, index_col=None, header=0, encoding = 'unicode_escape')
        fname = str(all_files[i]).split('\\')[-1:][0]
        fname1 = str(fname).split('-')[1]
        #print(fname1)
        tmp['state_name']=fname1
        df3= tmp[['Item','state_name','2014-15']]
        li.append(df3)
        
frame = pd.concat(li, axis=0, ignore_index=True, sort=True)
frame
# Out:
#          2014-15                                               Item  \
# 0     14819416.0                  Agriculture, forestry and fishing
# 1      7893514.0                                              Crops
# 2      4309078.0                                          Livestock
# 3       346160.0                               Forestry and logging
# 4      2270664.0                            Fishing and aquaculture
# 5      1484300.0                               Mining and quarrying
# 6     16303716.0                                            Primary
# 7      4672266.0                                      Manufacturing
# 8      1151729.0  Electricity, gas, water supply & other utility...
# 9      4664889.0                                       Construction
# 10    10488884.0                                          Secondary
# 11     4233400.0              Trade, repair, hotels and restaurants
# 12     3716000.0                            Trade & repair services
# ...

# %%
frame.columns
# Out:
# Index(['2014-15', 'Item', 'state_name'], dtype='object')

# %%
dfgsdpercapita= frame[frame['Item']=="Per Capita GSDP (Rs.)"].sort_values("2014-15",axis=0,ascending=True)
dfgsdpercapita
percapita = sns.barplot(x=dfgsdpercapita['state_name'], y=dfgsdpercapita['2014-15'])
percapita.set_xticklabels(percapita.get_xticklabels(), rotation=90)
plt.title("GSD PERCAPITA PER STATES")
plt.show()

# %%
top_5 = dfgsdpercapita.tail().sort_values("2014-15",axis=0,ascending=True)
percapita_top5 = sns.barplot(x=top_5['state_name'], y=top_5['2014-15'])
percapita_top5.set_xticklabels(percapita_top5.get_xticklabels(), rotation=90)
plt.title("GSD TOP 5 PERCAPITA  STATES")
plt.show()

# %%
bottom_5 = dfgsdpercapita.head().sort_values("2014-15",axis=0,ascending=True)
bottom_5 = sns.barplot(x=bottom_5['state_name'], y=bottom_5['2014-15'])
bottom_5.set_xticklabels(bottom_5.get_xticklabels(), rotation=90)
plt.title("GSD BOTTOM 5 PERCAPITA  STATES")
plt.show()

# %%
dfgsdpercapita_max= frame[frame['Item']=="Per Capita GSDP (Rs.)"].max()
dfgsdpercapita_min= frame[frame['Item']=='Per Capita GSDP (Rs.)'].min()

max_percapita = dfgsdpercapita_max['2014-15']
min_percapita = dfgsdpercapita_min['2014-15']

ratio_max_min = float(max_percapita/min_percapita)
round(ratio_max_min,2)
# Out:
# 8.0

# %%
frame_revised = frame[['Item','2014-15','state_name']]
frame_revised
# Out:
#                                                   Item      2014-15  \
# 0                    Agriculture, forestry and fishing   14819416.0
# 1                                                Crops    7893514.0
# 2                                            Livestock    4309078.0
# 3                                 Forestry and logging     346160.0
# 4                              Fishing and aquaculture    2270664.0
# 5                                 Mining and quarrying    1484300.0
# 6                                              Primary   16303716.0
# 7                                        Manufacturing    4672266.0
# 8    Electricity, gas, water supply & other utility...    1151729.0
# 9                                         Construction    4664889.0
# 10                                           Secondary   10488884.0
# 11               Trade, repair, hotels and restaurants    4233400.0
# 12                             Trade & repair services    3716000.0
# ...

# %%
type(frame_revised.index)
frame_revised_index = frame_revised.set_index('Item')

# %%
#primary
frame_revised_index.loc[['Primary', 'Secondary','Tertiary']]
# Out:
#               2014-15         state_name
# Item
# Primary    16303716.0     Andhra_Pradesh
# Primary      716959.0  Arunachal_Pradesh
# Primary     5326697.0              Assam
# Primary     8019997.0              Bihar
# Primary     6400817.0       Chhattisgarh
# Primary      312129.0                Goa
# Primary    15887187.0            Gujarat
# Primary     8040424.0            Haryana
# Primary     1548366.0   Himachal_Pradesh
# Primary     5248354.0          Jharkhand
# Primary    12066304.0          Karnataka
# Primary     6489442.0             Kerala
# Primary    17854020.0     Madhya_Pradesh
# Primary    21758383.0        Maharashtra
# Primary      383140.0            Manipur
# Primary      451050.0          Meghalaya
# Primary      225598.0            Mizoram
# Primary      616178.0           Nagaland
# Primary     9009306.0             Odisha
# Primary     9296070.0             Punjab
# Primary    19113780.0          Rajasthan
# Primary      138776.0             Sikkim
# ...

# %%
frame_PST=frame_revised[frame_revised["Item"].isin(["Primary", "Secondary", "Tertiary","Gross State Domestic Product"])]

# %%
frame_PST
# Out:
#                              Item      2014-15         state_name
# 6                         Primary   16303716.0     Andhra_Pradesh
# 10                      Secondary   10488884.0     Andhra_Pradesh
# 26                       Tertiary   22032942.0     Andhra_Pradesh
# 30   Gross State Domestic Product   52646842.0     Andhra_Pradesh
# 39                        Primary     716959.0  Arunachal_Pradesh
# 43                      Secondary     287489.0  Arunachal_Pradesh
# 59                       Tertiary     631844.0  Arunachal_Pradesh
# 63   Gross State Domestic Product    1676119.0  Arunachal_Pradesh
# 72                        Primary    5326697.0              Assam
# 76                      Secondary    4033091.0              Assam
# 92                       Tertiary    9307109.0              Assam
# 96   Gross State Domestic Product   19809800.0              Assam
# 105                       Primary    8019997.0              Bihar
# ...

# %%
table = pd.pivot(frame_PST, index ='state_name',columns ='Item', values='2014-15')
table
# Out:
# Item               Gross State Domestic Product     Primary   Secondary  \
# state_name
# Andhra_Pradesh                       52646842.0  16303716.0  10488884.0
# Arunachal_Pradesh                     1676119.0    716959.0    287489.0
# Assam                                19809800.0   5326697.0   4033091.0
# Bihar                                37391988.0   8019997.0   5984896.0
# Chhattisgarh                         23498180.0   6400817.0   8238886.0
# Goa                                   4063307.0    312129.0   1547536.0
# Gujarat                              89502727.0  15887187.0  33023538.0
# Haryana                              43746207.0   8040424.0  12561411.0
# Himachal_Pradesh                     10436879.0   1548366.0   4119162.0
# Jharkhand                            21710718.0   5248354.0   6241471.0
# Karnataka                            92178806.0  12066304.0  20484404.0
# Kerala                               52600230.0   6489442.0  12070040.0
# ...

# %%
table.columns
# Out:
# Index(['Gross State Domestic Product', 'Primary', 'Secondary', 'Tertiary'], dtype='object', name='Item')

# %%
gsdp_ratio=table

# %%
gsdp_ratio['Gross Over All'] = table['Gross State Domestic Product'].sum()

# %%
gsdp_ratio.columns
# Out:
# Index(['Gross State Domestic Product', 'Primary', 'Secondary', 'Tertiary',
#        'Gross Over All'],
#       dtype='object', name='Item')

# %%
gsdp_ratio['%primary']=round(100*(gsdp_ratio['Primary']/gsdp_ratio['Gross Over All']),2)
gsdp_ratio['%secondary']=round(100*(gsdp_ratio['Secondary']/gsdp_ratio['Gross Over All']),2)
gsdp_ratio['%tertiary']=round(100*(gsdp_ratio['Tertiary']/gsdp_ratio['Gross Over All']),2)
gsdp_ratio['%gsdp']=round(100*(gsdp_ratio['Gross State Domestic Product']/gsdp_ratio['Gross Over All']),2)

# %%
#gsdp_ratio = gsdp_ratio[['Primary','Secondary','Tertiary','Gross State Domestic Product','Gross Over All','%primary','%secondary','%tertiary']]

# %%
#gsdp_ratio['%gsdp']=round(100*(gsdp_ratio['Gross State Domestic Product']/gsdp_ratio['Gross Over All']),2)

# %%
gsdp_ratio
# Out:
# Item               Gross State Domestic Product     Primary   Secondary  \
# state_name
# Andhra_Pradesh                       52646842.0  16303716.0  10488884.0
# Arunachal_Pradesh                     1676119.0    716959.0    287489.0
# Assam                                19809800.0   5326697.0   4033091.0
# Bihar                                37391988.0   8019997.0   5984896.0
# Chhattisgarh                         23498180.0   6400817.0   8238886.0
# Goa                                   4063307.0    312129.0   1547536.0
# Gujarat                              89502727.0  15887187.0  33023538.0
# Haryana                              43746207.0   8040424.0  12561411.0
# Himachal_Pradesh                     10436879.0   1548366.0   4119162.0
# Jharkhand                            21710718.0   5248354.0   6241471.0
# Karnataka                            92178806.0  12066304.0  20484404.0
# Kerala                               52600230.0   6489442.0  12070040.0
# ...

# %%
gsdp_ratio.columns
# Out:
# Index(['Gross State Domestic Product', 'Primary', 'Secondary', 'Tertiary',
#        'Gross Over All', '%primary', '%secondary', '%tertiary', '%gsdp'],
#       dtype='object', name='Item')

# %%
gsdp_ratio_stack = gsdp_ratio[['%primary','%secondary','%tertiary','%gsdp']]

# %%
gsdp_ratio_stack.plot(kind='bar',stacked=True)

# %%
#for a,b in zip(frame_PST['Item'], frame_PST['2014-15']):
   # if(a=='Primary'):
        #print(b)
      #  prim=b
   # if(a=='Secondary'):
        #print(b)
     #   sec=b
   # if(a=='Gross State Domestic Product'):
        #print(b)
    #    gsdp=b

        
       # print("prim",prim)
       # print("sec",sec)
       # print("gsdp",gsdp)        
       # primper=100*(prim/gsdp)
       # print("primper",primper)
        
      #  frame_PST.append({'Item' : 'primper' , '2014-15' : primper},ignore_index=True)

# %%
frame_quantile=frame_revised[frame_revised["Item"].isin(["Agriculture, forestry and fishing","Mining and quarrying","Manufacturing","Electricity, gas, water supply & other utility services","Construction","Trade, repair, hotels and restaurants","Transport, storage, communication & services related to broadcasting","Financial services","Real estate, ownership of dwelling & professional services","Public administration","Other services","Per Capita GSDP (Rs.)"])]
frame_quantile
# Out:
#                                                   Item     2014-15  \
# 0                    Agriculture, forestry and fishing  14819416.0
# 5                                 Mining and quarrying   1484300.0
# 7                                        Manufacturing   4672266.0
# 8    Electricity, gas, water supply & other utility...   1151729.0
# 9                                         Construction   4664889.0
# 11               Trade, repair, hotels and restaurants   4233400.0
# 14   Transport, storage, communication & services r...   5076984.0
# 22                                  Financial services   1900863.0
# 23   Real estate, ownership of dwelling & professio...   4405409.0
# 24                               Public administration   2200897.0
# 25                                      Other services   4215389.0
# 32                               Per Capita GSDP (Rs.)    104977.0
# 33                   Agriculture, forestry and fishing    686117.0
# ...

# %%
frame_quantile_table = frame_quantile.pivot_table(index="state_name",columns="Item",values="2014-15")
frame_quantile_table
# Out:
# Item               Agriculture, forestry and fishing  Construction  \
# state_name
# Andhra_Pradesh                            14819416.0     4664889.0
# Arunachal_Pradesh                           686117.0      147842.0
# Assam                                      3855548.0     1733568.0
# Bihar                                      7951890.0     3449763.0
# Chhattisgarh                               3948847.0     2669855.0
# Goa                                         308507.0      165819.0
# Gujarat                                   13769969.0     5526017.0
# Haryana                                    8015238.0     3702571.0
# Himachal_Pradesh                           1514981.0      808256.0
# Jharkhand                                  3211065.0     1789834.0
# Karnataka                                 11219422.0     6104799.0
# Kerala                                     5930617.0     7314003.0
# Madhya_Pradesh                            16235647.0     4403151.0
# ...

# %%
#0.20     62989.00
#0.50     93647.00
#0.85    148710.75
#1.00    240274.00
quantile_20=round(frame_quantile_table['Per Capita GSDP (Rs.)'].quantile(0.20),2)
quantile_50=round(frame_quantile_table['Per Capita GSDP (Rs.)'].quantile(0.50),2)
quantile_85=round(frame_quantile_table['Per Capita GSDP (Rs.)'].quantile(0.85),2)
quantile_1=round(frame_quantile_table['Per Capita GSDP (Rs.)'].quantile(1.00),2)

# %%
print(quantile_1)
print(quantile_85)
# Out:
# 271793.0
# 153246.2

# %%
#C1=frame_quantile_table[frame_quantile_table['Per Capita GSDP (Rs.)']>=quantile_85]
C1 = frame_quantile_table[(frame_quantile_table['Per Capita GSDP (Rs.)'] >= quantile_85) & (frame_quantile_table['Per Capita GSDP (Rs.)'] <= quantile_1)]
C1
# Out:
# Item        Agriculture, forestry and fishing  Construction  \
# state_name
# Goa                                  308507.0      165819.0
# Haryana                             8015238.0     3702571.0
# Kerala                              5930617.0     7314003.0
# Sikkim                               137447.0       82058.0
#
# Item        Electricity, gas, water supply & other utility services  \
# state_name
# Goa                                                  204110.0
# Haryana                                             1101919.0
# Kerala                                               482470.0
# Sikkim                                               212499.0
#
# Item        Financial services  Manufacturing  Mining and quarrying  \
# state_name
# Goa                   233618.0      1177608.0                3622.0
# Haryana              1671486.0      7756921.0               25186.0
# Kerala               2010306.0      4273567.0              558824.0
# ...

# %%
C2 = frame_quantile_table[(frame_quantile_table['Per Capita GSDP (Rs.)'] >= quantile_50) & (frame_quantile_table['Per Capita GSDP (Rs.)'] < quantile_85)]
C2
# Out:
# Item               Agriculture, forestry and fishing  Construction  \
# state_name
# Andhra_Pradesh                            14819416.0     4664889.0
# Arunachal_Pradesh                           686117.0      147842.0
# Gujarat                                   13769969.0     5526017.0
# Himachal_Pradesh                           1514981.0      808256.0
# Karnataka                                 11219422.0     6104799.0
# Maharashtra                               16475655.0     9450211.0
# Punjab                                     9285716.0     2202962.0
# Tamil_Nadu                                13064238.0    12216718.0
# Telangana                                  7591501.0     2854024.0
# Uttarakhand                                1601423.0     1342733.0
#
# Item               Electricity, gas, water supply & other utility services  \
# state_name
# Andhra_Pradesh                                             1151729.0
# ...

# %%
C3 = frame_quantile_table[(frame_quantile_table['Per Capita GSDP (Rs.)'] >= quantile_20) & (frame_quantile_table['Per Capita GSDP (Rs.)'] < quantile_50)]
C3
# Out:
# Item          Agriculture, forestry and fishing  Construction  \
# state_name
# Chhattisgarh                          3948847.0     2669855.0
# Meghalaya                              366521.0      150256.0
# Mizoram                                217010.0      133228.0
# Nagaland                               607897.0      156072.0
# Odisha                                6422978.0     2402396.0
# Rajasthan                            15044394.0     5353326.0
# Tripura                                799825.0      177899.0
#
# Item          Electricity, gas, water supply & other utility services  \
# state_name
# Chhattisgarh                                          1198438.0
# Meghalaya                                               54473.0
# Mizoram                                                128365.0
# Nagaland                                                37944.0
# Odisha                                                 833067.0
# ...

# %%
C4 = frame_quantile_table[(frame_quantile_table['Per Capita GSDP (Rs.)'] >= 0) & (frame_quantile_table['Per Capita GSDP (Rs.)'] < quantile_20)]
C4
# Out:
# Item            Agriculture, forestry and fishing  Construction  \
# state_name
# Assam                                   3855548.0     1733568.0
# Bihar                                   7951890.0     3449763.0
# Jharkhand                               3211065.0     1789834.0
# Madhya_Pradesh                         16235647.0     4403151.0
# Manipur                                  383140.0      143182.0
# Uttar_Pradesh                          25097754.0    11256450.0
#
# Item            Electricity, gas, water supply & other utility services  \
# state_name
# Assam                                                    296587.0
# Bihar                                                    345168.0
# Jharkhand                                                337489.0
# Madhya_Pradesh                                          1272905.0
# Manipur                                                   27490.0
# Uttar_Pradesh                                           2030625.0
#
# ...

# %%
C4_sum_GSDP=C4['Per Capita GSDP (Rs.)'].sum()
C4['%Agri_forest_fishing']=round((C4['Agriculture, forestry and fishing']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
C4['%Electric&Utilities']=round((C4['Electricity, gas, water supply & other utility services']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#C4.drop(columns="%Agri_froest_fishin",inplace=True)

# %%
C4['%Construction']=round((C4['Construction']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
c4_sum=C4['Per Capita GSDP (Rs.)'].sum()
c4_sum
# Out:
# 327547.0

# %%
C4['%Fin_services']=round((C4['Financial services']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
C4['%Manu']=round((C4['Manufacturing']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
C4.fillna(value=0,inplace=True)
# Out:
# D:\Programs\anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
C4['%Mining&Quarrying']=round((C4['Mining and quarrying']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
C4['%Other_Services']=round((C4['Other services']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#C4
#Public administration
C4['%public_admin']=round((C4['Public administration']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#C4
#Real estate, ownership of dwelling & professional services
C4['%transport_comm_storage']=round((C4['Transport, storage, communication & services related to broadcasting']/C4['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
C4=C4[['%Agri_forest_fishing', '%Electric&Utilities', '%Construction','%Fin_services', '%Manu', '%Mining&Quarrying', '%Other_Services','%public_admin', '%real_estate', '%trade_repair','%transport_comm_storage']]
C4
# Out:
# Item            %Agri_forest_fishing  %Electric&Utilities  %Construction  \
# state_name
# Assam                          11.77                 0.91           5.29
# Bihar                          24.28                 1.05          10.53
# Jharkhand                       9.80                 1.03           5.46
# Madhya_Pradesh                 49.57                 3.89          13.44
# Manipur                         1.17                 0.08           0.44
# Uttar_Pradesh                  76.62                 6.20          34.37
#
# Item            %Fin_services  %Manu  %Mining&Quarrying  %Other_Services  \
# state_name
# Assam                    1.66   6.11               4.49             5.48
# Bihar                    3.60   6.69               0.21            14.01
# Jharkhand                1.68  12.56               6.22             4.20
# Madhya_Pradesh           6.07  13.34               4.94             8.39
# ...

# %%
ax = C4.plot.bar(stacked=False, edgecolor='none')
horiz_offset = 1.03
vert_offset = 1.
ax.legend(bbox_to_anchor=(horiz_offset, vert_offset))

# %%
C3_sum_GSDP=C3['Per Capita GSDP (Rs.)'].sum()
C3['%Agri_forest_fishing']=round((C3['Agriculture, forestry and fishing']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%Electric&Utilities']=round((C3['Electricity, gas, water supply & other utility services']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%Construction']=round((C3['Construction']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%Fin_services']=round((C3['Financial services']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%Manu']=round((C3['Manufacturing']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3.fillna(value=0,inplace=True)
C3['%Other_Services']=round((C3['Other services']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%public_admin']=round((C3['Public administration']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3['%transport_comm_storage']=round((C3['Transport, storage, communication & services related to broadcasting']/C3['Per Capita GSDP (Rs.)'].sum()),2)
C3
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
C3=C3[['%Agri_forest_fishing', '%Electric&Utilities', '%Construction','%Fin_services', '%Manu', '%Other_Services', '%public_admin','%transport_comm_storage']]
C3
# Out:
# Item          %Agri_forest_fishing  %Electric&Utilities  %Construction  \
# state_name
# Chhattisgarh                  6.73                 2.04           4.55
# Meghalaya                     0.62                 0.09           0.26
# Mizoram                       0.37                 0.22           0.23
# Nagaland                      1.04                 0.06           0.27
# Odisha                       10.95                 1.42           4.10
# Rajasthan                    25.65                 1.91           9.13
# Tripura                       1.36                 0.13           0.30
#
# Item          %Fin_services  %Manu  %Other_Services  %public_admin  \
# state_name
# Chhattisgarh           1.26   7.45             1.90           1.48
# Meghalaya              0.11   0.74             0.37           0.41
# Mizoram                0.04   0.01             0.32           0.35
# Nagaland               0.10   0.03             0.44           0.50
# ...

# %%
ax = C3.plot.bar(stacked=False, edgecolor='none')
horiz_offset = 1.03
vert_offset = 1.
ax.legend(bbox_to_anchor=(horiz_offset, vert_offset))

# %%
C2_sum_GSDP=C2['Per Capita GSDP (Rs.)'].sum()
C2['%Agri_forest_fishing']=round((C2['Agriculture, forestry and fishing']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%Electric&Utilities']=round((C2['Electricity, gas, water supply & other utility services']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%Construction']=round((C2['Construction']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%Fin_services']=round((C2['Financial services']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%Manu']=round((C2['Manufacturing']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2.fillna(value=0,inplace=True)
C2['%Other_Services']=round((C2['Other services']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%public_admin']=round((C2['Public administration']/C2['Per Capita GSDP (Rs.)'].sum()),2)
C2['%transport_comm_storage']=round((C2['Transport, storage, communication & services related to broadcasting']/C2['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
C2=C2[['%Agri_forest_fishing', '%Electric&Utilities', '%Construction','%Fin_services', '%Manu', '%Other_Services', '%public_admin','%transport_comm_storage']]
C2
# Out:
# Item               %Agri_forest_fishing  %Electric&Utilities  %Construction  \
# state_name
# Andhra_Pradesh                    10.82                 0.84           3.41
# Arunachal_Pradesh                  0.50                 0.08           0.11
# Gujarat                           10.05                 2.49           4.04
# Himachal_Pradesh                   1.11                 0.56           0.59
# Karnataka                          8.19                 1.04           4.46
# Maharashtra                       12.03                 3.17           6.90
# Punjab                             6.78                 0.67           1.61
# Tamil_Nadu                         9.54                 1.25           8.92
# Telangana                          5.54                 0.52           2.08
# Uttarakhand                        1.17                 0.32           0.98
#
# Item               %Fin_services  %Manu  %Other_Services  %public_admin  \
# state_name
# ...

# %%
ax = C2.plot.bar(stacked=False, edgecolor='none')
horiz_offset = 1.03
vert_offset = 1.
ax.legend(bbox_to_anchor=(horiz_offset, vert_offset))

# %%
C1_sum_GSDP=C1['Per Capita GSDP (Rs.)'].sum()
C1['%Agri_forest_fishing']=round((C1['Agriculture, forestry and fishing']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%Electric&Utilities']=round((C1['Electricity, gas, water supply & other utility services']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%Construction']=round((C1['Construction']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%Fin_services']=round((C1['Financial services']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%Manu']=round((C1['Manufacturing']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1.fillna(value=0,inplace=True)
C1['%Other_Services']=round((C1['Other services']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%public_admin']=round((C1['Public administration']/C1['Per Capita GSDP (Rs.)'].sum()),2)
C1['%transport_comm_storage']=round((C1['Transport, storage, communication & services related to broadcasting']/C1['Per Capita GSDP (Rs.)'].sum()),2)
# Out:
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
C1=C1[['%Agri_forest_fishing', '%Electric&Utilities', '%Construction','%Fin_services', '%Manu', '%Other_Services', '%public_admin','%transport_comm_storage']]
C1
# Out:
# Item        %Agri_forest_fishing  %Electric&Utilities  %Construction  \
# state_name
# Goa                         0.37                 0.25           0.20
# Haryana                     9.65                 1.33           4.46
# Kerala                      7.14                 0.58           8.80
# Sikkim                      0.17                 0.26           0.10
#
# Item        %Fin_services  %Manu  %Other_Services  %public_admin  \
# state_name
# Goa                  0.28   1.42             0.22           0.42
# Haryana              2.01   9.34             2.41           1.25
# Kerala               2.42   5.14             6.89           2.49
# Sikkim               0.03   0.66             0.18           0.14
#
# Item        %transport_comm_storage
# state_name
# Goa                            0.23
# Haryana                        3.08
# Kerala                         4.84
# Sikkim                         0.06

# %%
ax = C1.plot.bar(stacked=False, edgecolor='none')
horiz_offset = 1.03
vert_offset = 1.
ax.legend(bbox_to_anchor=(horiz_offset, vert_offset))

# %%
df_data = pd.read_csv("D:/upgrad/statsandEDA/data_rs.csv")

# %%
df_refined_data=df_data[['Sl. No.','Level of Education - State', 'Primary - 2014-2015.1','Upper Primary - 2014-2015','Secondary - 2014-2015','Senior Secondary - 2014-2015','GDP']]

# %%
df_refined_data.fillna(value=0, inplace=True)

# %%
df_refined_data.columns
# Out:
# Index(['Sl. No.', 'Level of Education - State', 'Primary - 2014-2015.1',
#        'Upper Primary - 2014-2015', 'Secondary - 2014-2015',
#        'Senior Secondary - 2014-2015', 'GDP'],
#       dtype='object')

# %%
df_refined_data.drop(['Sl. No.'], axis=1,inplace=True)
# Out:
# D:\Programs\anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_refined_data
# Out:
#    Level of Education - State  Primary - 2014-2015.1  \
# 0              Andhra Pradesh                   6.72
# 1           Arunachal Pradesh                  10.82
# 2                       Assam                  15.36
# 3                       Bihar                   0.00
# 4                 Chhatisgarh                   2.91
# 5                         Goa                   0.73
# 6                     Gujarat                   0.89
# 7                     Haryana                   5.61
# 8            Himachal Pradesh                   0.64
# 9                   Jharkhand                   5.48
# 10                  Karnataka                   2.02
# 11                     Kerala                   0.00
# 12             Madhya Pradesh                   6.59
# 13                Maharashtra                   1.26
# 14                    Manipur                   9.66
# 15                  Meghalaya                   9.46
# 16                    Mizoram                  10.10
# ...

# %%
corr_gdp = df_refined_data.corr()
round(corr_gdp,3)
# Out:
#                               Primary - 2014-2015.1  \
# Primary - 2014-2015.1                         1.000
# Upper Primary - 2014-2015                     0.660
# Secondary - 2014-2015                         0.188
# Senior Secondary - 2014-2015                 -0.062
# GDP                                          -0.468
#
#                               Upper Primary - 2014-2015  \
# Primary - 2014-2015.1                             0.660
# Upper Primary - 2014-2015                         1.000
# Secondary - 2014-2015                             0.604
# Senior Secondary - 2014-2015                     -0.132
# GDP                                              -0.561
#
#                               Secondary - 2014-2015  \
# Primary - 2014-2015.1                         0.188
# Upper Primary - 2014-2015                     0.604
# Secondary - 2014-2015                         1.000
# Senior Secondary - 2014-2015                 -0.162
# ...

# %%
#df_refined_data.columns
edu_primary=df_refined_data['Primary - 2014-2015.1']
edu_gdp = df_refined_data['GDP']

sns.lmplot('Primary - 2014-2015.1', 'GDP', data=df_refined_data, hue='Level of Education - State', fit_reg=False)

plt.show()

# %%
sns.lmplot('Upper Primary - 2014-2015', 'GDP', data=df_refined_data, hue='Level of Education - State', fit_reg=False)
plt.show()

# %%
sns.lmplot('Secondary - 2014-2015', 'GDP', data=df_refined_data, hue='Level of Education - State', fit_reg=False)
plt.show()

# %%
sns.lmplot('Senior Secondary - 2014-2015', 'GDP', data=df_refined_data, hue='Level of Education - State', fit_reg=False)
plt.show()
